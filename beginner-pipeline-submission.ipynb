# %% [markdown]
# # EDA + Preprocessing + Pipeline + Submission 🔥

# %%
# Import the necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import HistGradientBoostingClassifier
# %matplotlib inline
pd.options.display.max_columns = 40

import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# # EDA

# %%
# Reading the given input files
train = pd.read_csv("/kaggle/input/playground-series-s3e3/train.csv")
test = pd.read_csv("/kaggle/input/playground-series-s3e3/test.csv")
sub = pd.read_csv("/kaggle/input/playground-series-s3e3/sample_submission.csv")

# %%
train.head(3)
# Out:
#    id  Age     BusinessTravel  DailyRate              Department  \
# 0   0   36  Travel_Frequently        599  Research & Development
# 1   1   35      Travel_Rarely        921                   Sales
# 2   2   32      Travel_Rarely        718                   Sales
#
#    DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                24          3        Medical              1
# 1                 8          3          Other              1
# 2                26          3      Marketing              1
#
#    EnvironmentSatisfaction Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        4   Male          42               3         1
# 1                        1   Male          46               3         1
# 2                        3   Male          80               3         2
#
#                  JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0  Laboratory Technician                4       Married           2596
# 1   Sales Representative                1       Married           2899
# 2        Sales Executive                4      Divorced           4627
#
#    MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0         5099                   1      Y      Yes                 13
# 1        10778                   1      Y       No                 17
# 2        16495                   0      Y       No                 17
#
#    PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                  3                         2             80
# 1                  3                         4             80
# 2                  3                         4             80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 1                 10                      2
# 1                 1                  4                      3
# 2                 2                  4                      3
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                3              10                   0
# 1                3               4                   2
# 2                3               3                   2
#
#    YearsSinceLastPromotion  YearsWithCurrManager  Attrition
# 0                        7                     8          0
# 1                        0                     3          0
# 2                        1                     2          0

# %%
test.head(3)
# Out:
#      id  Age BusinessTravel  DailyRate              Department  \
# 0  1677   19     Non-Travel        992  Research & Development
# 1  1678   45  Travel_Rarely       1136                   Sales
# 2  1679   37  Travel_Rarely        155  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                 1          1        Medical              1
# 1                 4          4      Marketing              1
# 2                13          3  Life Sciences              1
#
#    EnvironmentSatisfaction Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        4   Male          43               3         1
# 1                        3   Male          67               3         2
# 2                        4   Male          41               3         1
#
#                  JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0  Laboratory Technician                3        Single           2318
# 1        Sales Executive                1      Divorced           5486
# 2     Research Scientist                4      Divorced           2741
#
#    MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0        17778                   1      Y       No                 12
# 1        12421                   6      Y      Yes                 12
# 2        23577                   4      Y      Yes                 13
#
#    PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                  3                         4             80
# 1                  3                         3             80
# 2                  3                         2             80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 0                  1                      2
# 1                 1                  7                      3
# 2                 2                 13                      2
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                2               1                   0
# 1                3               2                   2
# 2                2               7                   7
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     0
# 1                        2                     2
# 2                        1                     7

# %%
sub.head(3)
# Out:
#      id  Attrition
# 0  1677   0.119261
# 1  1678   0.119261
# 2  1679   0.119261

# %%
#Id and Employee number in the original dataset are like cardinal value so we are removing them
train_extra = train.drop("id", axis = 1)

# %% [markdown]
# We are going to add original dataset beacause it really improving our model.

# %%
#Adding the original dataset and making the dataset like our competion dataset adding it
original = pd.read_csv("/kaggle/input/ibm-hr-analytics-attrition-dataset/WA_Fn-UseC_-HR-Employee-Attrition.csv")
original = original.drop('EmployeeNumber', axis=1)
original["Attrition"] = original["Attrition"].apply(lambda x : 1 if x == "Yes" else 0)

# %%
new_train = pd.concat([original, train_extra], axis =0, ignore_index = True)

# %%
new_train
# Out:
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0      41          1      Travel_Rarely       1102                   Sales
# 1      49          0  Travel_Frequently        279  Research & Development
# 2      37          1      Travel_Rarely       1373  Research & Development
# 3      33          0  Travel_Frequently       1392  Research & Development
# 4      27          0      Travel_Rarely        591  Research & Development
# ...   ...        ...                ...        ...                     ...
# 3142   30          0      Travel_Rarely        945                   Sales
# 3143   32          0      Travel_Rarely       1303  Research & Development
# 3144   29          1  Travel_Frequently       1184         Human Resources
# 3145   36          0      Travel_Rarely        441                   Sales
# 3146   36          0      Travel_Rarely       1141  Research & Development
#
#       DistanceFromHome  Education   EducationField  EmployeeCount  \
# 0                    1          2    Life Sciences              1
# 1                    8          1    Life Sciences              1
# 2                    2          2            Other              1
# 3                    3          4    Life Sciences              1
# 4                    2          1          Medical              1
# ...                ...        ...              ...            ...
# 3142                 1          3    Life Sciences              1
# 3143                 2          3    Life Sciences              1
# 3144                24          3  Human Resources              1
# 3145                 9          2        Marketing              1
# 3146                20          3    Life Sciences              1
#
#       EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                           2  Female          94               3         2
# 1                           3    Male          61               2         2
# 2                           4    Male          92               2         1
# 3                           4  Female          56               3         1
# 4                           1    Male          40               3         1
# ...                       ...     ...         ...             ...       ...
# 3142                        4  Female          73               3         3
# 3143                        1    Male          48               3         1
# 3144                        2    Male          36               2         1
# 3145                        2    Male          48               4         2
# 3146                        3  Female          35               3         1
#
#                     JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0           Sales Executive                4        Single           5993
# 1        Research Scientist                2       Married           5130
# 2     Laboratory Technician                3        Single           2090
# 3        Research Scientist                3       Married           2909
# 4     Laboratory Technician                2       Married           3468
# ...                     ...              ...           ...            ...
# 3142        Sales Executive                3        Single           8722
# 3143     Research Scientist                2       Married           3544
# 3144        Human Resources                1       Married           2804
# 3145        Sales Executive                3      Divorced           5406
# 3146  Laboratory Technician                3        Single           2593
#
#       MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0           19479                   8      Y      Yes                 11
# 1           24907                   1      Y       No                 23
# 2            2396                   6      Y      Yes                 15
# 3           23159                   1      Y      Yes                 11
# 4           16632                   9      Y       No                 12
# ...           ...                 ...    ...      ...                ...
# 3142        14255                   1      Y       No                 19
# 3143        15972                   4      Y       No                 19
# 3144        15322                   1      Y      Yes                 11
# 3145         4051                   1      Y       No                 21
# 3146        17381                   0      Y       No                 19
#
#       PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                     3                         1             80
# 1                     4                         4             80
# 2                     3                         2             80
# 3                     3                         3             80
# 4                     3                         4             80
# ...                 ...                       ...            ...
# 3142                  3                         2             80
# 3143                  3                         4             80
# 3144                  3                         3             80
# 3145                  4                         3             80
# 3146                  3                         4             80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                  8                      0
# 1                    1                 10                      3
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# ...                ...                ...                    ...
# 3142                 0                 10                      2
# 3143                 1                 10                      3
# 3144                 0                  1                      2
# 3145                 2                 10                      3
# 3146                 0                 10                      3
#
#       WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                   1               6                   4
# 1                   3              10                   7
# 2                   3               0                   0
# 3                   3               8                   7
# 4                   3               2                   2
# ...               ...             ...                 ...
# 3142                4              10                   0
# 3143                4               4                   2
# 3144                3               1                   0
# 3145                2              10                   3
# 3146                2               8                   2
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# ...                       ...                   ...
# 3142                        0                     8
# 3143                        1                     3
# 3144                        0                     0
# 3145                        0                     8
# 3146                        7                     3
#
# [3147 rows x 34 columns]

# %% [markdown]
# # EDA

# %%
#Finding Missing values
new_train.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
#Finding Missing values
test.isna().sum()
# Out:
# id                          0
# Age                         0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
new_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3147 entries, 0 to 3146
# Data columns (total 34 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                
{
#   background-color: #b8e3b2;
#   color: #000000;
# }
# #T_e9b4d_row1_col0, #T_e9b4d_row1_col2, #T_e9b4d_row1_col4, #T_e9b4d_row1_col6, #T_e9b4d_row1_col8, #T_e9b4d_row1_col9, #T_e9b4d_row1_col10, #T_e9b4d_row1_col11, #T_e9b4d_row1_col16, #T_e9b4d_row1_col18, #T_e9b4d_row1_col19, #T_e9b4d_row1_col20, #T_e9b4d_row1_col21, #T_e9b4d_row1_col22, #T_e9b4d_row1_col23, #T_e9b4d_row1_col25, #T_e9b4d_row6_col15, #T

# %%
new_train["EmployeeCount"].value_counts()
# Out:
# 1    3147
# Name: EmployeeCount, dtype: int64

# %%
new_train.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
new_train.Attrition.value_counts()
# Out:
# 0    2710
# 1     437
# Name: Attrition, dtype: int64

# %%
cat_col = [col for col in new_train.columns if new_train[col].dtypes == 'O']

# %%
cont_col = [col for col in new_train.columns if new_train[col].dtypes != 'O']

# %%
cat_col
# Out:
# ['BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'JobRole',
#  'MaritalStatus',
#  'Over18',
#  'OverTime']

# %%
cont_col
# Out:
# ['Age',
#  'Attrition',
#  'DailyRate',
#  'DistanceFromHome',
#  'Education',
#  'EmployeeCount',
#  'EnvironmentSatisfaction',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobLevel',
#  'JobSatisfaction',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StandardHours',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %% [markdown]
# # Preprocessing

# %% [markdown]
# Basic structure
# 1.Not a time series(Random split of train test split can be done)
# 2. Doesn't contain missing values
# 3. Contain categorical data
# 4. Need a normalization

# %%
train_full = new_train.copy()

# %%
train_full[cat_col]
# Out:
#          BusinessTravel              Department   EducationField  Gender  \
# 0         Travel_Rarely                   Sales    Life Sciences  Female
# 1     Travel_Frequently  Research & Development    Life Sciences    Male
# 2         Travel_Rarely  Research & Development            Other    Male
# 3     Travel_Frequently  Research & Development    Life Sciences  Female
# 4         Travel_Rarely  Research & Development          Medical    Male
# ...                 ...                     ...              ...     ...
# 3142      Travel_Rarely                   Sales    Life Sciences  Female
# 3143      Travel_Rarely  Research & Development    Life Sciences    Male
# 3144  Travel_Frequently         Human Resources  Human Resources    Male
# 3145      Travel_Rarely                   Sales        Marketing    Male
# 3146      Travel_Rarely  Research & Development    Life Sciences  Female
#
#                     JobRole MaritalStatus Over18 OverTime
# 0           Sales Executive        Single      Y      Yes
# 1        Research Scientist       Married      Y       No
# 2     Laboratory Technician        Single      Y      Yes
# 3        Research Scientist       Married      Y      Yes
# 4     Laboratory Technician       Married      Y       No
# ...                     ...           ...    ...      ...
# 3142        Sales Executive        Single      Y       No
# 3143     Research Scientist       Married      Y       No
# 3144        Human Resources       Married      Y      Yes
# 3145        Sales Executive      Divorced      Y       No
# 3146  Laboratory Technician        Single      Y       No
#
# [3147 rows x 8 columns]

# %%
train_full[cont_col]
# Out:
#       Age  Attrition  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0      41          1       1102                 1          2              1
# 1      49          0        279                 8          1              1
# 2      37          1       1373                 2          2              1
# 3      33          0       1392                 3          4              1
# 4      27          0        591                 2          1              1
# ...   ...        ...        ...               ...        ...            ...
# 3142   30          0        945                 1          3              1
# 3143   32          0       1303                 2          3              1
# 3144   29          1       1184                24          3              1
# 3145   36          0        441                 9          2              1
# 3146   36          0       1141                20          3              1
#
#       EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# 0                           2          94               3         2
# 1                           3          61               2         2
# 2                           4          92               2         1
# 3                           4          56               3         1
# 4                           1          40               3         1
# ...                       ...         ...             ...       ...
# 3142                        4          73               3         3
# 3143                        1          48               3         1
# 3144                        2          36               2         1
# 3145                        2          48               4         2
# 3146                        3          35               3         1
#
#       JobSatisfaction  MonthlyIncome  MonthlyRate  NumCompaniesWorked  \
# 0                   4           5993        19479                   8
# 1                   2           5130        24907                   1
# 2                   3           2090         2396                   6
# 3                   3           2909        23159                   1
# 4                   2           3468        16632                   9
# ...               ...            ...          ...                 ...
# 3142                3           8722        14255                   1
# 3143                2           3544        15972                   4
# 3144                1           2804        15322                   1
# 3145                3           5406         4051                   1
# 3146                3           2593        17381                   0
#
#       PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 0                    11                  3                         1
# 1                    23                  4                         4
# 2                    15                  3                         2
# 3                    11                  3                         3
# 4                    12                  3                         4
# ...                 ...                ...                       ...
# 3142                 19                  3                         2
# 3143                 19                  3                         4
# 3144                 11                  3                         3
# 3145                 21                  4                         3
# 3146                 19                  3                         4
#
#       StandardHours  StockOptionLevel  TotalWorkingYears  \
# 0                80                 0                  8
# 1                80                 1                 10
# 2                80                 0                  7
# 3                80                 0                  8
# 4                80                 1                  6
# ...             ...               ...                ...
# 3142             80                 0                 10
# 3143             80                 1                 10
# 3144             80                 0                  1
# 3145             80                 2                 10
# 3146             80                 0                 10
#
#       TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0                         0                1               6
# 1                         3                3              10
# 2                         3                3               0
# 3                         3                3               8
# 4                         3                3               2
# ...                     ...              ...             ...
# 3142                      2                4              10
# 3143                      3                4               4
# 3144                      2                3               1
# 3145                      3                2              10
# 3146                      3                2               8
#
#       YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                      4                        0                     5
# 1                      7                        1                     7
# 2                      0                        0                     0
# 3                      7                        3                     0
# 4                      2                        2                     2
# ...                  ...                      ...                   ...
# 3142                   0                        0                     8
# 3143                   2                        1                     3
# 3144                   0                        0                     0
# 3145                   3                        0                     8
# 3146                   2                        7                     3
#
# [3147 rows x 26 columns]

# %%
train_model = train_full.drop("Attrition", axis = 1)
train_model
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 0      41      Travel_Rarely       1102                   Sales
# 1      49  Travel_Frequently        279  Research & Development
# 2      37      Travel_Rarely       1373  Research & Development
# 3      33  Travel_Frequently       1392  Research & Development
# 4      27      Travel_Rarely        591  Research & Development
# ...   ...                ...        ...                     ...
# 3142   30      Travel_Rarely        945                   Sales
# 3143   32      Travel_Rarely       1303  Research & Development
# 3144   29  Travel_Frequently       1184         Human Resources
# 3145   36      Travel_Rarely        441                   Sales
# 3146   36      Travel_Rarely       1141  Research & Development
#
#       DistanceFromHome  Education   EducationField  EmployeeCount  \
# 0                    1          2    Life Sciences              1
# 1                    8          1    Life Sciences              1
# 2                    2          2            Other              1
# 3                    3          4    Life Sciences              1
# 4                    2          1          Medical              1
# ...                ...        ...              ...            ...
# 3142                 1          3    Life Sciences              1
# 3143                 2          3    Life Sciences              1
# 3144                24          3  Human Resources              1
# 3145                 9          2        Marketing              1
# 3146                20          3    Life Sciences              1
#
#       EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                           2  Female          94               3         2
# 1                           3    Male          61               2         2
# 2                           4    Male          92               2         1
# 3                           4  Female          56               3         1
# 4                           1    Male          40               3         1
# ...                       ...     ...         ...             ...       ...
# 3142                        4  Female          73               3         3
# 3143                        1    Male          48               3         1
# 3144                        2    Male          36               2         1
# 3145                        2    Male          48               4         2
# 3146                        3  Female          35               3         1
#
#                     JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0           Sales Executive                4        Single           5993
# 1        Research Scientist                2       Married           5130
# 2     Laboratory Technician                3        Single           2090
# 3        Research Scientist                3       Married           2909
# 4     Laboratory Technician                2       Married           3468
# ...                     ...              ...           ...            ...
# 3142        Sales Executive                3        Single           8722
# 3143     Research Scientist                2       Married           3544
# 3144        Human Resources                1       Married           2804
# 3145        Sales Executive                3      Divorced           5406
# 3146  Laboratory Technician                3        Single           2593
#
#       MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0           19479                   8      Y      Yes                 11
# 1           24907                   1      Y       No                 23
# 2            2396                   6      Y      Yes                 15
# 3           23159                   1      Y      Yes                 11
# 4           16632                   9      Y       No                 12
# ...           ...                 ...    ...      ...                ...
# 3142        14255                   1      Y       No                 19
# 3143        15972                   4      Y       No                 19
# 3144        15322                   1      Y      Yes                 11
# 3145         4051                   1      Y       No                 21
# 3146        17381                   0      Y       No                 19
#
#       PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                     3                         1             80
# 1                     4                         4             80
# 2                     3                         2             80
# 3                     3                         3             80
# 4                     3                         4             80
# ...                 ...                       ...            ...
# 3142                  3                         2             80
# 3143                  3                         4             80
# 3144                  3                         3             80
# 3145                  4                         3             80
# 3146                  3                         4             80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                  8                      0
# 1                    1                 10                      3
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# ...                ...                ...                    ...
# 3142                 0                 10                      2
# 3143                 1                 10                      3
# 3144                 0                  1                      2
# 3145                 2                 10                      3
# 3146                 0                 10                      3
#
#       WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                   1               6                   4
# 1                   3              10                   7
# 2                   3               0                   0
# 3                   3               8                   7
# 4                   3               2                   2
# ...               ...             ...                 ...
# 3142                4              10                   0
# 3143                4               4                   2
# 3144                3               1                   0
# 3145                2              10                   3
# 3146                2               8                   2
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# ...                       ...                   ...
# 3142                        0                     8
# 3143                        1                     3
# 3144                        0                     0
# 3145                        0                     8
# 3146                        7                     3
#
# [3147 rows x 33 columns]

# %%
X = train_model

# %%
X
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 0      41      Travel_Rarely       1102                   Sales
# 1      49  Travel_Frequently        279  Research & Development
# 2      37      Travel_Rarely       1373  Research & Development
# 3      33  Travel_Frequently       1392  Research & Development
# 4      27      Travel_Rarely        591  Research & Development
# ...   ...                ...        ...                     ...
# 3142   30      Travel_Rarely        945                   Sales
# 3143   32      Travel_Rarely       1303  Research & Development
# 3144   29  Travel_Frequently       1184         Human Resources
# 3145   36      Travel_Rarely        441                   Sales
# 3146   36      Travel_Rarely       1141  Research & Development
#
#       DistanceFromHome  Education   EducationField  EmployeeCount  \
# 0                    1          2    Life Sciences              1
# 1                    8          1    Life Sciences              1
# 2                    2          2            Other              1
# 3                    3          4    Life Sciences              1
# 4                    2          1          Medical              1
# ...                ...        ...              ...            ...
# 3142                 1          3    Life Sciences              1
# 3143                 2          3    Life Sciences              1
# 3144                24          3  Human Resources              1
# 3145                 9          2        Marketing              1
# 3146                20          3    Life Sciences              1
#
#       EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                           2  Female          94               3         2
# 1                           3    Male          61               2         2
# 2                           4    Male          92               2         1
# 3                           4  Female          56               3         1
# 4                           1    Male          40               3         1
# ...                       ...     ...         ...             ...       ...
# 3142                        4  Female          73               3         3
# 3143                        1    Male          48               3         1
# 3144                        2    Male          36               2         1
# 3145                        2    Male          48               4         2
# 3146                        3  Female          35               3         1
#
#                     JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0           Sales Executive                4        Single           5993
# 1        Research Scientist                2       Married           5130
# 2     Laboratory Technician                3        Single           2090
# 3        Research Scientist                3       Married           2909
# 4     Laboratory Technician                2       Married           3468
# ...                     ...              ...           ...            ...
# 3142        Sales Executive                3        Single           8722
# 3143     Research Scientist                2       Married           3544
# 3144        Human Resources                1       Married           2804
# 3145        Sales Executive                3      Divorced           5406
# 3146  Laboratory Technician                3        Single           2593
#
#       MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0           19479                   8      Y      Yes                 11
# 1           24907                   1      Y       No                 23
# 2            2396                   6      Y      Yes                 15
# 3           23159                   1      Y      Yes                 11
# 4           16632                   9      Y       No                 12
# ...           ...                 ...    ...      ...                ...
# 3142        14255                   1      Y       No                 19
# 3143        15972                   4      Y       No                 19
# 3144        15322                   1      Y      Yes                 11
# 3145         4051                   1      Y       No                 21
# 3146        17381                   0      Y       No                 19
#
#       PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                     3                         1             80
# 1                     4                         4             80
# 2                     3                         2             80
# 3                     3                         3             80
# 4                     3                         4             80
# ...                 ...                       ...            ...
# 3142                  3                         2             80
# 3143                  3                         4             80
# 3144                  3                         3             80
# 3145                  4                         3             80
# 3146                  3                         4             80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                  8                      0
# 1                    1                 10                      3
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# ...                ...                ...                    ...
# 3142                 0                 10                      2
# 3143                 1                 10                      3
# 3144                 0                  1                      2
# 3145                 2                 10                      3
# 3146                 0                 10                      3
#
#       WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                   1               6                   4
# 1                   3              10                   7
# 2                   3               0                   0
# 3                   3               8                   7
# 4                   3               2                   2
# ...               ...             ...                 ...
# 3142                4              10                   0
# 3143                4               4                   2
# 3144                3               1                   0
# 3145                2              10                   3
# 3146                2               8                   2
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# ...                       ...                   ...
# 3142                        0                     8
# 3143                        1                     3
# 3144                        0                     0
# 3145                        0                     8
# 3146                        7                     3
#
# [3147 rows x 33 columns]

# %%
y = train_full["Attrition"]

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 3142    0
# 3143    0
# 3144    1
# 3145    0
# 3146    0
# Name: Attrition, Length: 3147, dtype: int64

# %%
#Taking small amount of data for Validation
X_train, X_valid,y_train, y_valid = train_test_split(X, y,test_size = 0.15 ,random_state = 42)

# %%
X_train.shape, y_train.shape
# Out:
# ((2674, 33), (2674,))

# %%
X_valid.shape, y_valid.shape
# Out:
# ((473, 33), (473,))

# %% [markdown]
# # Bundle up the preprocessing by making pipeline

# %%
numerical_col = make_pipeline(StandardScaler(with_mean = False))
categorical_col = make_pipeline(OneHotEncoder(),
                               StandardScaler(with_mean = False))

# %%
#Removing the target column
cont_col.remove("Attrition")

# %%
preprocessor = make_column_transformer(
    (numerical_col, cont_col),
    (categorical_col, cat_col))

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('pipeline-1',
#                                  Pipeline(steps=[('standardscaler',
#                                                   StandardScaler(with_mean=False))]),
#                                  ['Age', 'DailyRate', 'DistanceFromHome',
#                                   'Education', 'EmployeeCount',
#                                   'EnvironmentSatisfaction', 'HourlyRate',
#                                   'JobInvolvement', 'JobLevel',
#                                   'JobSatisfaction', 'MonthlyIncome',
#                                   'MonthlyRate', 'NumCompaniesWorked',
#                                   'PercentSalaryHike', 'PerformanceR...
#                                   'TrainingTimesLastYear', 'WorkLifeBalance',
#                                   'YearsAtCompany', 'YearsInCurrentRole',
#                                   'YearsSinceLastPromotion',
#                                   'YearsWithCurrManager']),
#                                 ('pipeline-2',
#                                  Pipeline(steps=[('onehotencoder',
#                                                   OneHotEncoder()),
#                                                  ('standardscaler',
#                                                   StandardScaler(with_mean=False))]),
#                                  ['BusinessTravel', 'Department',
#                                   'EducationField', 'Gender', 'JobRole',
#                                   'MaritalStatus', 'Over18', 'OverTime'])])

# %% [markdown]
# # Random Forest

# %%
model = RandomForestClassifier(n_estimators=500, random_state=42)
my_pipeline = make_pipeline(preprocessor,
                           model)

# %%
my_pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('standardscaler',
#                                                                    StandardScaler(with_mean=False))]),
#                                                   ['Age', 'DailyRate',
#                                                    'DistanceFromHome',
#                                                    'Education', 'EmployeeCount',
#                                                    'EnvironmentSatisfaction',
#                                                    'HourlyRate',
#                                                    'JobInvolvement', 'JobLevel',
#                                                    'JobSatisfaction',
#                                                    'MonthlyIncome',
#                                                    'MonthlyRate',
#                                                    'NumCompaniesWork...
#                                                    'YearsSinceLastPromotion',
#                                                    'YearsWithCurrManager']),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('onehotencoder',
#                                                                    OneHotEncoder()),
#                                                                   ('standardscaler',
#                                                                    StandardScaler(with_mean=False))]),
#                                                   ['BusinessTravel',
#                                                    'Department',
#                                                    'EducationField', 'Gender',
#                                                    'JobRole', 'MaritalStatus',
#                                                    'Over18', 'OverTime'])])),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(n_estimators=500, random_state=42))])

# %%
preds = my_pipeline.score(X_valid, y_valid)

# %%
preds
# Out:
# 0.879492600422833

# %% [markdown]
# # Gradient Boosting

# %%
model1 = HistGradientBoostingClassifier(learning_rate=0.001)

# %%
my_pipeline1 = make_pipeline(preprocessor,
                           model1)

# %%
my_pipeline1.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('standardscaler',
#                                                                    StandardScaler(with_mean=False))]),
#                                                   ['Age', 'DailyRate',
#                                                    'DistanceFromHome',
#                                                    'Education', 'EmployeeCount',
#                                                    'EnvironmentSatisfaction',
#                                                    'HourlyRate',
#                                                    'JobInvolvement', 'JobLevel',
#                                                    'JobSatisfaction',
#                                                    'MonthlyIncome',
#                                                    'MonthlyRate',
#                                                    'NumCompaniesWork...
#                                                    'YearsSinceLastPromotion',
#                                                    'YearsWithCurrManager']),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('onehotencoder',
#                                                                    OneHotEncoder()),
#                                                                   ('standardscaler',
#                                                                    StandardScaler(with_mean=False))]),
#                                                   ['BusinessTravel',
#                                                    'Department',
#                                                    'EducationField', 'Gender',
#                                                    'JobRole', 'MaritalStatus',
#                                                    'Over18', 'OverTime'])])),
#                 ('histgradientboostingclassifier',
#                  HistGradientBoostingClassifier(learning_rate=0.001))])

# %%
my_pipeline1.score(X_valid, y_valid)
# Out:
# 0.8668076109936576

# %%
test.columns
# Out:
# Index(['id', 'Age', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
test = test.drop(["id"], axis=1)

# %% [markdown]
# # Submitting the prediction with pipeline which is made of random forest

# %%
sub1 = my_pipeline.predict(test)

# %%
sub1
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
# Submission
rf_sub = pd.DataFrame({"id": sub.id, "Attrition": sub1})

# %%
rf_sub.head()
# Out:
#      id  Attrition
# 0  1677          0
# 1  1678          0
# 2  1679          0
# 3  1680          0
# 4  1681          1

# %%
rf_sub.to_csv("submission.csv", index = False)

# %% [markdown]
# # Note
# 1. There are lot more work todo like feature importance, hyper parameter tuning trying various model which will increase the accuracy.
# 2. One lesson i learned today is start a competition early which gives more time to spend on.
# 3. I am a big fan of fastai this notebookis more of tradition way of solving problems.
